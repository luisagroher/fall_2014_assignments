# %% [markdown]
# These are powerful new tools; used today to answer the unanswerable
# and start life-changing companies.  One part math, one part programming,
# and a whole lot of creativity:
# data science is an art that cannot be learned from a textbook.
# Dataset: SuperHappyFunDataSet.csv.
# Raw financial data from Bloomberg.  Don't be fooled by the name.
# This is the devil incarnate!
#
# The variable of interest is the U.S. 10-year Treasury yield.
# This is the interest rate paid on U.S. Trearusy debt.
#
# These financial instruments are generally considered risk-free
# and their yield is the benchmark of global economic stability.
# Today the price of oil is $89/gallon.
#
# If OPEC acts to restrict supply it will do so to defend a
# $100 price floor.  What effect will this $11.00 price
# change have on U.S. 10-year Treasury yields?
#
# How confident are you with your answer?

# %%
pwd
# Out:
# u'/home/vagrant/notebooks/fall_2014_assignments/dataexplor03/luisagroher'

# %%
cd /home/vagrant/notebooks/fall_2014_assignments
# Out:
# /home/vagrant/notebooks/fall_2014_assignments

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
import os

data = pd.read_csv(os.path.join('dataexplor03', 'SuperHappyFunDataSet.csv')).dropna()

# %%
len(data)
# Out:
# 2451

# %%
data.head()
# Out:
#   LIBOR_date  LIBOR_price  OIS_date  OIS_price  Oil_date  Oil_price  \
# 0   1/2/2003      1.38000  1/1/2003      1.231  1/2/2003      31.85
# 1   1/3/2003      1.39000  1/2/2003      1.226  1/3/2003      33.08
# 2   1/6/2003      1.38875  1/3/2003      1.234  1/6/2003      32.10
# 3   1/7/2003      1.38750  1/6/2003      1.237  1/7/2003      31.08
# 4   1/8/2003      1.38000  1/7/2003      1.234  1/8/2003      30.56
#
#   US_equity_index_date  US_equity_index US10Y_date  US10Y_yield  \
# 0             1/2/2003           909.03   1/1/2003       3.8175
# 1             1/3/2003           908.59   1/2/2003       4.0305
# 2             1/6/2003           929.01   1/3/2003       4.0169
# 3             1/7/2003           922.93   1/6/2003       4.0518
# 4             1/8/2003           909.93   1/7/2003       4.0053
#
#   USD_trade_weighted_date  USD_trade_weighted_index
# 0                1/2/2003                    101.88
# 1                1/3/2003                    101.69
# ...

# %%
dat = data.loc[:,'OIS_date':'OIS_price'].merge(data.loc[:,'LIBOR_date':'LIBOR_price'] , left_on='OIS_date', right_on='LIBOR_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price
# 0  1/1/2003      1.231        NaN          NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000
# 2  1/3/2003      1.234   1/3/2003      1.39000
# 3  1/6/2003      1.237   1/6/2003      1.38875
# 4  1/7/2003      1.234   1/7/2003      1.38750

# %%
dat = dat.merge(data.loc[:,'Oil_date':'Oil_price'], left_on='OIS_date', right_on='Oil_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price  Oil_date  Oil_price
# 0  1/1/2003      1.231        NaN          NaN       NaN        NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000  1/2/2003      31.85
# 2  1/3/2003      1.234   1/3/2003      1.39000  1/3/2003      33.08
# 3  1/6/2003      1.237   1/6/2003      1.38875  1/6/2003      32.10
# 4  1/7/2003      1.234   1/7/2003      1.38750  1/7/2003      31.08

# %% [markdown]
# dat = dat.merge(data.loc[:,'US_equity_index_date':'US_equity_index'], left_on='OIS_date', right_on='US_equity_index_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price  Oil_date  Oil_price
# 0  1/1/2003      1.231        NaN          NaN       NaN        NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000  1/2/2003      31.85
# 2  1/3/2003      1.234   1/3/2003      1.39000  1/3/2003      33.08
# 3  1/6/2003      1.237   1/6/2003      1.38875  1/6/2003      32.10
# 4  1/7/2003      1.234   1/7/2003      1.38750  1/7/2003      31.08

# %%
dat = dat.merge(data.loc[:,'US_equity_index_date': 'US_equity_index'], left_on='OIS_date', right_on='US_equity_index_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price  Oil_date  Oil_price  \
# 0  1/1/2003      1.231        NaN          NaN       NaN        NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000  1/2/2003      31.85
# 2  1/3/2003      1.234   1/3/2003      1.39000  1/3/2003      33.08
# 3  1/6/2003      1.237   1/6/2003      1.38875  1/6/2003      32.10
# 4  1/7/2003      1.234   1/7/2003      1.38750  1/7/2003      31.08
#
#   US_equity_index_date  US_equity_index
# 0                  NaN              NaN
# 1             1/2/2003           909.03
# 2             1/3/2003           908.59
# 3             1/6/2003           929.01
# 4             1/7/2003           922.93

# %%
dat = dat.merge(data.loc[:, 'US10Y_date':'US10Y_yield'], left_on='OIS_date', right_on='US10Y_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price  Oil_date  Oil_price  \
# 0  1/1/2003      1.231        NaN          NaN       NaN        NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000  1/2/2003      31.85
# 2  1/3/2003      1.234   1/3/2003      1.39000  1/3/2003      33.08
# 3  1/6/2003      1.237   1/6/2003      1.38875  1/6/2003      32.10
# 4  1/7/2003      1.234   1/7/2003      1.38750  1/7/2003      31.08
#
#   US_equity_index_date  US_equity_index US10Y_date  US10Y_yield
# 0                  NaN              NaN   1/1/2003       3.8175
# 1             1/2/2003           909.03   1/2/2003       4.0305
# 2             1/3/2003           908.59   1/3/2003       4.0169
# 3             1/6/2003           929.01   1/6/2003       4.0518
# 4             1/7/2003           922.93   1/7/2003       4.0053

# %%
dat = dat.merge(data.loc[:,'USD_trade_weighted_date':'USD_trade_weighted_index'], left_on='OIS_date', right_on='USD_trade_weighted_date', how='left')

# %%
dat.head()
# Out:
#    OIS_date  OIS_price LIBOR_date  LIBOR_price  Oil_date  Oil_price  \
# 0  1/1/2003      1.231        NaN          NaN       NaN        NaN
# 1  1/2/2003      1.226   1/2/2003      1.38000  1/2/2003      31.85
# 2  1/3/2003      1.234   1/3/2003      1.39000  1/3/2003      33.08
# 3  1/6/2003      1.237   1/6/2003      1.38875  1/6/2003      32.10
# 4  1/7/2003      1.234   1/7/2003      1.38750  1/7/2003      31.08
#
#   US_equity_index_date  US_equity_index US10Y_date  US10Y_yield  \
# 0                  NaN              NaN   1/1/2003       3.8175
# 1             1/2/2003           909.03   1/2/2003       4.0305
# 2             1/3/2003           908.59   1/3/2003       4.0169
# 3             1/6/2003           929.01   1/6/2003       4.0518
# 4             1/7/2003           922.93   1/7/2003       4.0053
#
#   USD_trade_weighted_date  USD_trade_weighted_index
# 0                     NaN                       NaN
# 1                1/2/2003                    101.88
# ...

# %%
sns.corrplot(data)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=bold:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
sns.corrplot(dat)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
sns.corrplot(dat)

# %%
dat = dat.dropna()

# %%
data.head()
# Out:
#   LIBOR_date  LIBOR_price  OIS_date  OIS_price  Oil_date  Oil_price  \
# 0   1/2/2003      1.38000  1/1/2003      1.231  1/2/2003      31.85
# 1   1/3/2003      1.39000  1/2/2003      1.226  1/3/2003      33.08
# 2   1/6/2003      1.38875  1/3/2003      1.234  1/6/2003      32.10
# 3   1/7/2003      1.38750  1/6/2003      1.237  1/7/2003      31.08
# 4   1/8/2003      1.38000  1/7/2003      1.234  1/8/2003      30.56
#
#   US_equity_index_date  US_equity_index US10Y_date  US10Y_yield  \
# 0             1/2/2003           909.03   1/1/2003       3.8175
# 1             1/3/2003           908.59   1/2/2003       4.0305
# 2             1/6/2003           929.01   1/3/2003       4.0169
# 3             1/7/2003           922.93   1/6/2003       4.0518
# 4             1/8/2003           909.93   1/7/2003       4.0053
#
#   USD_trade_weighted_date  USD_trade_weighted_index
# 0                1/2/2003                    101.88
# 1                1/3/2003                    101.69
# ...

# %%
from datetime import datetime

# %%
datestr = data['LIBOR_date']

# %%
print type(data['LIBOR_date'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
dateTest = datetime(2014,7,4)
print dateTest
print type(dateTest)
# Out:
# 2014-07-04 00:00:00
# <type 'datetime.datetime'>

# %%
dat['OIS_date'] = pd.to_datetime(dat['OIS_date'])
dat['LIBOR_date'] = pd.to_datetime(dat['LIBOR_date'])
dat['Oil_date'] = pd.to_datetime(dat['Oil_date'])
dat['US_equity_index_date'] = pd.to_datetime(dat['US_equity_index_date'])
dat['US10Y_date'] = pd.to_datetime(dat['US10Y_date'])
dat['USD_trade_weighted_date'] = pd.to_datetime(dat['USD_trade_weighted_date'])
D = dat['US10Y_date']

# %%
print type(D)
# Out:
# <class 'pandas.core.series.Series'>

# %%
dat.head(2)
# Out:
#     OIS_date  OIS_price LIBOR_date  LIBOR_price   Oil_date  Oil_price  \
# 1 2003-01-02      1.226 2003-01-02         1.38 2003-01-02      31.85
# 2 2003-01-03      1.234 2003-01-03         1.39 2003-01-03      33.08
#
#   US_equity_index_date  US_equity_index US10Y_date  US10Y_yield  \
# 1           2003-01-02           909.03 2003-01-02       4.0305
# 2           2003-01-03           908.59 2003-01-03       4.0169
#
#   USD_trade_weighted_date  USD_trade_weighted_index
# 1              2003-01-02                    101.88
# 2              2003-01-03                    101.69

# %%
####Looks like has been converted to time series even though type does't indicate this as time series.

# %%
X = dat.Oil_price
y = dat.US10Y_yield

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(20,5))

ax1.plot(D, y)
ax2.plot(D, X)

# %%
X1 = np.log(X)
y1 = np.log(y)

# %%
f, ax = plt.subplots(figsize=[20,5])
plt.plot(D, y1)
plt.plot(D, X1)

# %%
### simple linear regression

# %%
model = LinearRegression(fit_intercept=True)
X = X.reshape((X.shape[0], 1))
y = y.reshape((y.shape[0], 1))
model.fit(X, y)
print ("Model coefficient: %.5f, and intercept: %.5f"
       % (model.coef_, model.intercept_))
# Out:
# Model coefficient: -0.01145, and intercept: 4.57068

# %%
X_test = np.linspace(160, 1, 100).reshape(100,1)
y_hat = model.predict(X_test)
plt.plot(X, y, 'o')
plt.plot(X_test, y_hat)

# %%
model.predict(100)
# Out:
# array([[ 3.42611863]])

# %%
### check
print dat.US10Y_yield[2200]
print dat.Oil_price[2200]
# Out:
# 2.9387
# 100.74

# %%
import statsmodels.formula.api as smf

# %%
###Simple Linear Regression could be fairly close even though these two prices are not highly correlated and the above graph is a collosal mess

# %%
stats_model = smf.ols(formula='y ~ X', data=dat)
fit = stats_model.fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     310.2
# Date:                Wed, 19 Nov 2014   Prob (F-statistic):           3.23e-65
# Time:                        17:58:48   Log-Likelihood:                -2694.6
# No. Observations:                2294   AIC:                             5393.
# Df Residuals:                    2292   BIC:                             5405.
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      4.5707      0.047     96.235      0.000         4.478     4.664
# X             -0.0114      0.001    -17.612      0.000        -0.013    -0.010
# ...

# %%
plt.plot(y, X, 'o')
plt.plot(y, fit.fittedvalues)
plt.xlabel('Oil_price')
plt.ylabel('US10Y_yield')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
####hist of residuals

# %%
influence = fit.get_influence()
(c, p) = influence.cooks_distance
plt.stem(np.arange(len(c)), c, markerfmt=",")
# Out:
# <Container object of 3 artists>

# %%
import statsmodels.formula.api as smf
import statsmodels.graphics.regressionplots as smg


smg.influence_plot(fit, criterion="cooks")
smg.plot_leverage_resid2(fit)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=16.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=x-large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
####messy

# %%
### i don't think that the date is set up correctly in this analysis and the whole analysis is thrown off by this.
